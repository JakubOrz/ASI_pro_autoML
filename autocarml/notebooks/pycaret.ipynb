# %%
import pandas as pd
from pycaret.regression import *

# %%
data_frame = pd.read_csv("../data/01_raw/car_prices_small.csv", error_bad_lines=False)

# %%
data_frame['saledate'] = pd.to_datetime(data_frame['saledate'], utc=True)

# %%
data_frame.dtypes
# Out:
# year                          int64
# make                         object
# model                        object
# trim                         object
# body                         object
# transmission                 object
# vin                          object
# state                        object
# condition                   float64
# odometer                      int64
# color                        object
# interior                     object
# seller                       object
# mmr                           int64
# sellingprice                  int64
# saledate        datetime64[ns, UTC]
# dtype: object

# %%
data_frame.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0     16639  white    black
# 1  5xyktca69fg561319    ca        5.0      9393  white    beige
# 2  wba3c1c51ek116351    ca        4.5      1331   gray    black
# 3  yv1612tb4f1310987    ca        4.1     14282  white    black
# 4  wba6b2c57ed129731    ca        4.3      2641   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america, inc  20500         21500
# ...

# %%
data_frame.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
data_frame.shape
# Out:
# (31, 16)

# %%
model_setup = setup(data=data_frame, target="sellingprice")
# Out:
# <style type="text/css">
# #T_717bf_row3_col1, #T_717bf_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_717bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_717bf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_717bf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_717bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_717bf_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_717bf_row0_col1" class="data row0 col1" >7566</td>
#     </tr>
#     <tr>
#       <th id="T_717bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_717bf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_717bf_row1_col1" class="data row1 col1" >sellingprice</td>
#     </tr>
#     <tr>
#       <th id="T_717bf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model =compare_models()
# Out:
# <style type="text/css">
# #T_62d38 th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
output_df = model_setup.predict_model(best_model, data=data_frame)
